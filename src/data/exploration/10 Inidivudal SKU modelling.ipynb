# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')
sns.plotting_context(context='paper')
sns.set_palette('rainbow')

import pickle
import pandas as pd

# %%
sales = pd.read_csv('../../../data/mckinsey/sales.csv', index_col='ID')
skus = pd.read_csv('../../../data/mckinsey/sku.csv', index_col='SKU')

covid_response = pd.read_excel('../../../data/oxford/OxCGRT_timeseries_all.xlsx')

sales = sales.join(skus, on='SKU')

sales['date'] = pd.to_datetime(sales['date'])
sales = sales.loc[sales['date'] > '2020-04-01']

sales_to_predict = pd.read_csv('../../../data/mckinsey/test.csv', index_col='ID')
sales_to_predict['date'] = pd.to_datetime(sales_to_predict['date'])
sales.fillna(1, inplace=True)

# %%
timeframe = pd.date_range(start=sales['date'].min(), end=sales['date'].max(), freq='D')

# %%
additional_clusters_added = sales.groupby('geoCluster')['date'].min().reset_index().groupby('date')['geoCluster'].count()
geoclusters_cumsum = additional_clusters_added.reindex(timeframe, fill_value=0).cumsum()

avg_covid_response = covid_response.select_dtypes('number').mean()
avg_covid_response.index = pd.to_datetime(avg_covid_response.index)

# %%
sku_daily_sales = sales.groupby('SKU').apply(lambda x: x.groupby('date')['sales'].sum().reindex(timeframe, fill_value=0)).transpose()

# %%
fig, ax = plt.subplots(figsize=(15, 5))

sku_daily_sales.plot(ax=ax, alpha=0.2, color='blue')
ax.get_legend().remove()

# %% [markdown]
# #### Seperate models for each SKU

# %%
with open('../../../data/sku_price_histories.pickle', 'rb') as handle:
    price_histories = pickle.load(handle)

# %%
import neuralprophet

skus = sales['SKU'].unique()

models = {}

for sku in skus:
    sku_sales = sales[sales['SKU'] == sku].copy()
    sku_sales = sku_sales.groupby('date')['sales'].sum().reindex(timeframe, fill_value=0).reset_index()

    sku_sales.rename(columns={'index': 'ds', 'sales': 'y'}, inplace=True)

    model = neuralprophet.NeuralProphet()
    model.add_country_holidays(country_name='US', lower_window=-2, upper_window=2)

    model.add_future_regressor('covid_response')
    model.add_future_regressor('active_geoclusters')
    model.add_future_regressor('price')

    sku_sales = sku_sales.join(avg_covid_response.rename('covid_response'), on='ds')
    sku_sales = sku_sales.join(geoclusters_cumsum.rename('active_geoclusters'), on='ds')
    sku_sales = sku_sales.join(price_histories[sku], on='ds')

    model.fit(sku_sales)

    models[sku] = model
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.783% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Linus Folkerts\Documents\HackUPC\hackupc-demand-forecasting\src\data\exploration\10 Inidivudal SKU modelling.ipynb Cell 9' in <cell line: 7>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Linus%20Folkerts/Documents/HackUPC/hackupc-demand-forecasting/src/data/exploration/10%20Inidivudal%20SKU%20modelling.ipynb#ch0000012?line=19'>20</a> sku_sales = sku_sales.join(geoclusters_cumsum.rename('active_geoclusters'), on='ds')
#      <a href='vscode-notebook-cell:/c%3A/Users/Linus%20Folkerts/Documents/HackUPC/hackupc-demand-forecasting/src/data/exploration/10%20Inidivudal%20SKU%20modelling.ipynb#ch0000012?line=20'>21</a> sku_sales = sku_sales.join(price_histories[sku], on='ds')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Linus%20Folkerts/Documents/HackUPC/hackupc-demand-forecasting/src/data/exploration/10%20Inidivudal%20SKU%20modelling.ipynb#ch0000012?line=22'>23</a> model.fit(sku_sales)
#      <a href='vscode-notebook-cell:/c%3A/Users/Linus%20Folkerts/Documents/HackUPC/hackupc-demand-forecasting/src/data/exploration/10%20Inidivudal%20SKU%20modelling.ipynb#ch0000012?line=24'>25</a> models[sku] = model
#
# File ~\.conda\envs\hackupc-demand-forecasting\lib\site-packages\neuralprophet\forecaster.py:592, in NeuralProphet.fit(self, df, freq, validation_df, progress, minimal)
#     <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=589'>590</a>         metrics_df = None
#     <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=590'>591</a>     else:
# --> <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=591'>592</a>         metrics_df = self._train(df_dict, progress=progress)
#     <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=592'>593</a> else:
#     <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=593'>594</a>     df_val_dict, _ = df_utils.prep_copy_df_dict(validation_df)
#
# File ~\.conda\envs\hackupc-demand-forecasting\lib\site-packages\neuralprophet\forecaster.py:1806, in NeuralProphet._train(self, df_dict, df_val_dict, progress)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1802'>1803</a>     return self._train_minimal(df_dict, progress_bar=progress_bar)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1804'>1805</a> # set up data loader
# -> <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1805'>1806</a> loader = self._init_train_loader(df_dict)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1806'>1807</a> # set up Metrics
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1807'>1808</a> if self.highlight_forecast_step_n is not None:
#
# File ~\.conda\envs\hackupc-demand-forecasting\lib\site-packages\neuralprophet\forecaster.py:1579, in NeuralProphet._init_train_loader(self, df_dict)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1570'>1571</a> # if not self.fitted:
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1571'>1572</a> self.config_normalization.init_data_params(
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1572'>1573</a>     df_dict=df_dict,
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1573'>1574</a>     covariates_config=self.config_covar,
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1574'>1575</a>     regressor_config=self.regressors_config,
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1575'>1576</a>     events_config=self.events_config,
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1576'>1577</a> )
# -> <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1578'>1579</a> df_dict = self._normalize(df_dict)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1579'>1580</a> # if not self.fitted:
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1580'>1581</a> if self.config_trend.changepoints is not None:
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1581'>1582</a>     # scale user-specified changepoint times
#
# File ~\.conda\envs\hackupc-demand-forecasting\lib\site-packages\neuralprophet\forecaster.py:1554, in NeuralProphet._normalize(self, df_dict)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1551'>1552</a> for df_name, df_i in df_dict.items():
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1552'>1553</a>     data_params = self.config_normalization.get_data_params(df_name)
# -> <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1553'>1554</a>     df_dict[df_name] = df_utils.normalize(df_i, data_params)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/forecaster.py?line=1554'>1555</a> return df_dict
#
# File ~\.conda\envs\hackupc-demand-forecasting\lib\site-packages\neuralprophet\df_utils.py:348, in normalize(df, data_params)
#     <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/df_utils.py?line=345'>346</a> for name in df.columns:
#     <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/df_utils.py?line=346'>347</a>     if name not in data_params.keys():
# --> <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/df_utils.py?line=347'>348</a>         raise ValueError("Unexpected column {} in data".format(name))
#     <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/df_utils.py?line=348'>349</a>     new_name = name
#     <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/neuralprophet/df_utils.py?line=349'>350</a>     if name == "ds":
#
# ValueError: Unexpected column price in data

# %%
with open('../../../data/sku_prediction_models.pickle', 'wb') as handle:
    pickle.dump(models, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
sku = 24

sales = sku_daily_sales[sku].reset_index().rename(columns={'sales': 'ds', sku: 'y'})

sales = sales.join(avg_covid_response.rename('covid_response'), on='ds')
sales = sales.join(geoclusters_cumsum.rename('active_geoclusters'), on='ds')

prediction = models[sku].predict(sales)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.783% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.783% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D

# %%
fig, ax = plt.subplots(figsize=(12, 4))

prediction.plot(ax=ax, x='ds', y=['y', 'yhat1'])
# Out:
# <AxesSubplot:xlabel='ds'>

# %% [markdown]
# #### Map predictions too test.csv

# %%
prediction_validation_set = pd.read_csv('../../../data/mckinsey/test.csv', index_col='ID')
prediction_validation_set['date'] = pd.to_datetime(prediction_validation_set['date'])

# %%
prediction_validation_set.loc[prediction_validation_set['SKU'] == 32485].sort_values('date')
# Out:
#             geoCluster    SKU        date  price_filled  sales
# ID
# RR29287638        2114  32485  2021-07-06         41.29    NaN
# RR28451109        2025  32485  2021-07-06         41.29    NaN
# RR27964126        1297  32485  2021-07-06         39.69    NaN
# RR31310812        3080  32485  2021-07-06         38.29    NaN
# RR30766295        2510  32485  2021-07-06         43.99    NaN
# ...                ...    ...         ...           ...    ...
# RR30374671        2273  32485  2021-07-19         35.59    NaN
# RR29228581        2105  32485  2021-07-19         35.59    NaN
# RR29240318        2106  32485  2021-07-19         35.59    NaN
# RR29176341        2087  32485  2021-07-19         38.39    NaN
# RR31318871        3230  32485  2021-07-19         36.19    NaN
#
# [5500 rows x 5 columns]

# %%
sales.loc[sales['SKU'] == 32485]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\hackupc-demand-forecasting\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~\.conda\envs\hackupc-demand-forecasting\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.conda\envs\hackupc-demand-forecasting\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SKU'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Linus Folkerts\Documents\HackUPC\hackupc-demand-forecasting\src\data\exploration\10 Inidivudal SKU modelling.ipynb Cell 16' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Linus%20Folkerts/Documents/HackUPC/hackupc-demand-forecasting/src/data/exploration/10%20Inidivudal%20SKU%20modelling.ipynb#ch0000032?line=0'>1</a> sales.loc[sales['SKU'] == 32485]
#
# File ~\.conda\envs\hackupc-demand-forecasting\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~\.conda\envs\hackupc-demand-forecasting\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/Linus%20Folkerts/.conda/envs/hackupc-demand-forecasting/lib/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'SKU'
